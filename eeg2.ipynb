# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/EEG.machinelearing_data_BRMH.csv")
df.head()
# Out:
#    no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0    1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1    2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2    3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3    4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4    5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
#
#       specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0  Alcohol use disorder         35.998557         21.717375  ...
# 1  Alcohol use disorder         13.425118         11.002916  ...
# 2  Alcohol use disorder         29.941780         27.544684  ...
# 3  Alcohol use disorder         21.496226         21.846832  ...
# 4  Alcohol use disorder         37.775667         33.607679  ...
#
#    COH.F.gamma.o.Pz.p.P4  COH.F.gamma.o.Pz.q.T6  COH.F.gamma.o.Pz.r.O1  \
# 0              55.989192              16.739679              23.452271
# ...

# %%
df.describe()
# Out:
#               no.         age   education          IQ  AB.A.delta.a.FP1  \
# count  945.000000  945.000000  930.000000  932.000000        945.000000
# mean   473.000000   30.594804   13.438710  101.580472         20.182936
# std    272.942302   11.781592    2.550461   17.022414         11.282022
# min      1.000000   18.000000    0.000000   49.000000          3.272260
# 25%    237.000000   21.730000   12.000000   91.000000         12.784872
# 50%    473.000000   26.150000   13.000000  102.000000         17.065286
# 75%    709.000000   35.450000   16.000000  114.000000         24.492760
# max    945.000000   71.880000   20.000000  145.000000         92.826192
#
#        AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  \
# count        945.000000       945.000000       945.000000       945.000000
# mean          21.177584        17.749553        18.901698        20.447079
# std           12.230662        10.003598         9.079482         9.742912
# ...

# %%
sns.displot(data=df, x='IQ', hue='main.disorder', kind='kde', fill=True)
plt.title('Frequency Distribution of IQ for Each Class')
plt.xlabel('IQ')
plt.ylabel('Density')
plt.show()

# %%
gender_order = ['Male', 'Female']

# Create the bar plot
sns.set_style('whitegrid')
plt.figure(figsize=(12, 6))

# Group the data by 'main.disorder' and 'Gender', count occurrences, and unstack to get separate columns for each gender
df_grouped = df.groupby(['main.disorder', 'sex']).size().unstack()

# Plot each gender as a stacked bar within each disorder
df_grouped.plot(kind='bar', stacked=True, color=['#1f77b4', '#ff7f0e'], width=0.7)

# Set plot title and labels
plt.title('Gender Distribution Across Disorders')
plt.xlabel('Disorder')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')

# Show legend
plt.legend(title='Gender', labels=gender_order)

# Show plot
plt.tight_layout()
plt.show()

# %%
gender_counts = df['sex'].value_counts()

# Display the total count of males and females
print("Total Males:", gender_counts['M'])
print("Total Females:", gender_counts['F'])
# Out:
# Total Males: 601
# Total Females: 344

# %%
df1 = df.filter(regex='^(?!.*COH)')

# %%
df1.head()
# Out:
#    no. sex   age    eeg.date  education     IQ       main.disorder  \
# 0    1   M  57.0   2012.8.30        NaN    NaN  Addictive disorder
# 1    2   M  37.0    2012.9.6        6.0  120.0  Addictive disorder
# 2    3   M  32.0   2012.9.10       16.0  113.0  Addictive disorder
# 3    4   M  35.0   2012.10.8       18.0  126.0  Addictive disorder
# 4    5   M  36.0  2012.10.18       16.0  112.0  Addictive disorder
#
#       specific.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  ...  \
# 0  Alcohol use disorder         35.998557         21.717375  ...
# 1  Alcohol use disorder         13.425118         11.002916  ...
# 2  Alcohol use disorder         29.941780         27.544684  ...
# 3  Alcohol use disorder         21.496226         21.846832  ...
# 4  Alcohol use disorder         37.775667         33.607679  ...
#
#    AB.F.gamma.k.C4  AB.F.gamma.l.T4  AB.F.gamma.m.T5  AB.F.gamma.n.P3  \
# 0         1.765493         1.464281         1.501948         1.707307
# ...

# %%
specific_counts = df['specific.disorder'].value_counts()
specific_counts
# Out:
# Depressive disorder               199
# Schizophrenia                     117
# Healthy control                    95
# Alcohol use disorder               93
# Behavioral addiction disorder      93
# Bipolar disorder                   67
# Panic disorder                     59
# Posttraumatic stress disorder      52
# Social anxiety disorder            48
# Obsessive compulsitve disorder     46
# Acute stress disorder              38
# Adjustment disorder                38
# Name: specific.disorder, dtype: int64

# %%
columns_to_remove = ['education', 'date', 'Unnamed: 122','no.']
df2 = df1.drop(columns=columns_to_remove, errors='ignore')
df2.head()
# Out:
#   sex   age    eeg.date     IQ       main.disorder     specific.disorder  \
# 0   M  57.0   2012.8.30    NaN  Addictive disorder  Alcohol use disorder
# 1   M  37.0    2012.9.6  120.0  Addictive disorder  Alcohol use disorder
# 2   M  32.0   2012.9.10  113.0  Addictive disorder  Alcohol use disorder
# 3   M  35.0   2012.10.8  126.0  Addictive disorder  Alcohol use disorder
# 4   M  36.0  2012.10.18  112.0  Addictive disorder  Alcohol use disorder
#
#    AB.A.delta.a.FP1  AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  ...  \
# 0         35.998557         21.717375        21.518280        26.825048  ...
# 1         13.425118         11.002916        11.942516        15.272216  ...
# 2         29.941780         27.544684        17.150159        23.608960  ...
# 3         21.496226         21.846832        17.364316        13.833701  ...
# 4         37.775667         33.607679        21.865556        21.771413  ...
#
# ...

# %%
columns_to_remove = ['education', 'date', 'Unnamed: 122','no.','eeg.date']
df2 = df1.drop(columns=columns_to_remove, errors='ignore')
df2.head()
# Out:
#   sex   age     IQ       main.disorder     specific.disorder  \
# 0   M  57.0    NaN  Addictive disorder  Alcohol use disorder
# 1   M  37.0  120.0  Addictive disorder  Alcohol use disorder
# 2   M  32.0  113.0  Addictive disorder  Alcohol use disorder
# 3   M  35.0  126.0  Addictive disorder  Alcohol use disorder
# 4   M  36.0  112.0  Addictive disorder  Alcohol use disorder
#
#    AB.A.delta.a.FP1  AB.A.delta.b.FP2  AB.A.delta.c.F7  AB.A.delta.d.F3  \
# 0         35.998557         21.717375        21.518280        26.825048
# 1         13.425118         11.002916        11.942516        15.272216
# 2         29.941780         27.544684        17.150159        23.608960
# 3         21.496226         21.846832        17.364316        13.833701
# 4         37.775667         33.607679        21.865556        21.771413
#
#    AB.A.delta.e.Fz  ...  AB.F.gamma.j.Cz  AB.F.gamma.k.C4  AB.F.gamma.l.T4  \
# 0        26.611516  ...         1.993727         1.765493         1.464281
# ...

# %%
df2.isnull().sum()
df3 = df2.dropna()
df3.head()
df3.describe()
# Out:
#               age          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# count  932.000000  932.000000        932.000000        932.000000
# mean    30.626792  101.580472         20.168390         21.179384
# std     11.791844   17.022414         11.327940         12.294138
# min     18.000000   49.000000          3.272260          3.244199
# 25%     21.812500   91.000000         12.693472         12.924297
# 50%     26.160000  102.000000         17.015539         17.758077
# 75%     35.482500  114.000000         24.396304         25.708689
# max     71.880000  145.000000         92.826192        101.515687
#
#        AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# count       932.000000       932.000000       932.000000       932.000000
# mean         17.773391        18.880762        20.431109        19.466896
# std          10.047112         9.104100         9.776948         9.273608
# min           3.050507         3.412618         5.066593         4.048931
# ...

# %%
df3['sex'] = df3['sex'].replace({'M': 0, 'F': 1})
df3=df3.drop(['specific.disorder'],axis=1)
df3.head()
df3.describe()
# Out:
# <ipython-input-17-66ac10e156a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['sex'] = df3['sex'].replace({'M': 0, 'F': 1})
#               sex         age          IQ  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# count  932.000000  932.000000  932.000000        932.000000        932.000000
# mean     0.362661   30.626792  101.580472         20.168390         21.179384
# std      0.481026   11.791844   17.022414         11.327940         12.294138
# min      0.000000   18.000000   49.000000          3.272260          3.244199
# 25%      0.000000   21.812500   91.000000         12.693472         12.924297
# 50%      0.000000   26.160000  102.000000         17.015539         17.758077
# ...

# %%
sex_dummies = pd.get_dummies(df3['sex'], prefix='sex')

# Concatenate the dummy variables with the original DataFrame
df_encoded = pd.concat([df3, sex_dummies], axis=1)

# Drop the original 'sex' column
df_encoded.drop('sex', axis=1, inplace=True)

# Display the DataFrame with one-hot encoded 'sex' column
df_encoded.head()
# Out:
#     age     IQ       main.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 1  37.0  120.0  Addictive disorder         13.425118         11.002916
# 2  32.0  113.0  Addictive disorder         29.941780         27.544684
# 3  35.0  126.0  Addictive disorder         21.496226         21.846832
# 4  36.0  112.0  Addictive disorder         37.775667         33.607679
# 5  24.0  105.0  Addictive disorder         13.482096         14.095855
#
#    AB.A.delta.c.F7  AB.A.delta.d.F3  AB.A.delta.e.Fz  AB.A.delta.f.F4  \
# 1        11.942516        15.272216        14.151570        12.456034
# 2        17.150159        23.608960        27.087811        13.541237
# 3        17.364316        13.833701        14.100954        13.100939
# 4        21.865556        21.771413        22.854536        21.456377
# 5        12.854630        11.727480        13.128924        11.627138
#
#    AB.A.delta.g.F8  ...  AB.F.gamma.l.T4  AB.F.gamma.m.T5  AB.F.gamma.n.P3  \
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming df is your DataFrame containing the data
X = df3.drop(columns=['main.disorder'])  # Features

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Set the number of top principal components (k)
k = 10  # Change this to the desired number of components

# Perform PCA with the specified number of components
pca = PCA(n_components=20)
X_pca = pca.fit_transform(X_scaled)

# Print the explained variance ratio of each principal component
# print("Explained Variance Ratio of Each Principal Component:")
# print(pca.explained_variance_ratio_)
# print(pca)

pca_components = pca.components_

# Print the shape of the components
print("Shape of PCA components:", pca_components.shape)

# Print the coefficients
print("PCA Coefficients:")
print(pca_components)
# Out:
# Shape of PCA components: (20, 117)
# PCA Coefficients:
# [[ 0.0041381   0.00068274 -0.01353169 ...  0.07762601  0.05690305
#    0.05286083]
#  [-0.01176381  0.00478481 -0.00153524 ...  0.12630652  0.08837765
#    0.08242905]
#  [ 0.01564905 -0.00856881  0.01600456 ... -0.04199678 -0.02994868
#   -0.04050234]
#  ...
#  [-0.54104882  0.43976232 -0.29584211 ...  0.07708881 -0.07164721
#    0.0575938 ]
#  [ 0.1044889  -0.13106915  0.15802091 ...  0.03430025  0.16928025
#    0.15199046]
#  [-0.13095723  0.16978745 -0.07764147 ... -0.0378033  -0.01681427
#    0.05633516]]

# %%
pca_path = '/content/drive/My Drive/models/pca_model.pkl'
with open('pca_model.pkl', 'wb') as file:
    pickle.dump(pca, file)

# %%
# from sklearn.decomposition import PCA
# from sklearn.preprocessing import StandardScaler

# # Assuming df is your DataFrame containing the data
# X = df3.drop(columns=['main.disorder'])  # Features

# # Standardize the features
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Perform PCA
# pca = PCA()
# X_pca = pca.fit_transform(X_scaled)

# # Calculate cumulative explained variance ratio
# explained_variance_ratio_cumulative = pca.explained_variance_ratio_.cumsum()

# # Find the index where cumulative explained variance ratio exceeds or equals 0.9
# k = next(i for i, explained_variance in enumerate(explained_variance_ratio_cumulative) if explained_variance >= 0.9) + 1

# # Use the top k principal components
# pca = PCA(n_components=k)
# X_pca_top_k = pca.fit_transform(X_scaled)

# # Print the number of components needed to explain 90% of the variance
# print("Number of components needed to explain 90% of the variance:", k)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier

# Assuming X_pca_top_k contains the top k principal components
# Assuming y contains the target labels (main disorders)

# Split the data into training and testing sets
y=df3['main.disorder']
X_train=X_pca
y_train=y
# X_test=X_pca
# y_test=y
X_train, X_test1, y_train, y_test1 = train_test_split(X_pca, y, test_size=0.1, random_state=42)
X_test, X_test2, y_test, y_test1 = train_test_split(X_pca, y, test_size=0.1, random_state=45)

# Train a Random Forest classifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(X_train, y_train)
rf_accuracy = rf_classifier.score(X_test, y_test)
print("Random Forest Classifier Accuracy:", rf_accuracy)

# Train a Support Vector Machine (SVM) classifier
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)
svm_accuracy = svm_classifier.score(X_test, y_test)
print("SVM Classifier Accuracy:", svm_accuracy)

# Train a Gradient Boosting classifier
gb_classifier = GradientBoostingClassifier()
gb_classifier.fit(X_train, y_train)
gb_accuracy = gb_classifier.score(X_test, y_test)
print("Gradient Boosting Classifier Accuracy:", gb_accuracy)

# Train an AdaBoost classifier
ab_classifier = AdaBoostClassifier()
ab_classifier.fit(X_train, y_train)
ab_accuracy = ab_classifier.score(X_test, y_test)
print("AdaBoost Classifier Accuracy:", ab_accuracy)

# Train a Gaussian Naive Bayes classifier
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
nb_accuracy = nb_classifier.score(X_test, y_test)
print("Gaussian Naive Bayes Classifier Accuracy:", nb_accuracy)

# Train a Multi-layer Perceptron (Neural Network) classifier
mlp_classifier = MLPClassifier()
mlp_classifier.fit(X_train, y_train)
mlp_accuracy = mlp_classifier.score(X_test, y_test)
print("Neural Network Classifier Accuracy:", mlp_accuracy)
# Out:
# Random Forest Classifier Accuracy: 0.9272076372315036
# SVM Classifier Accuracy: 0.4081145584725537
# Gradient Boosting Classifier Accuracy: 0.9164677804295943
# AdaBoost Classifier Accuracy: 0.315035799522673
# Gaussian Naive Bayes Classifier Accuracy: 0.2720763723150358
# Neural Network Classifier Accuracy: 0.6348448687350835
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

n_clusters = 7  # Choose the number of clusters
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
cluster_labels = kmeans.fit_predict(X_pca)

# Visualize the clusters
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Clustered Disorders (based on Principal Components)')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# import pickle

# model_path = '/content/drive/My Drive/models/rf_model.pkl'
# with open(model_path, 'wb') as file:
#     pickle.dump(rf_classifier, file)

# %%
with open('/content/rf_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)



print("Model loaded successfully.")
print("Model type:", type(loaded_model))
# Out:
# Model loaded successfully.
# Model type: <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %%
X_pca[0]
# Out:
# array([ 1.39225911e+00,  1.40840118e-01,  5.10923291e+00,  5.50118836e+00,
#         2.43232996e-01,  2.31146704e+00,  6.90001350e-01,  5.34103132e-01,
#        -1.51712640e+00,  5.95975926e-01, -2.99820847e-01,  1.39813139e+00,
#        -6.62877684e-01,  1.09207084e+00, -4.25337558e-04, -5.32537745e-01,
#        -4.00934011e-01,  1.11737490e+00,  5.73856990e-01,  4.80206210e-01])

# %%
df3
# Out:
#      sex   age     IQ       main.disorder  AB.A.delta.a.FP1  AB.A.delta.b.FP2  \
# 1      0  37.0  120.0  Addictive disorder         13.425118         11.002916
# 2      0  32.0  113.0  Addictive disorder         29.941780         27.544684
# 3      0  35.0  126.0  Addictive disorder         21.496226         21.846832
# 4      0  36.0  112.0  Addictive disorder         37.775667         33.607679
# 5      1  24.0  105.0  Addictive disorder         13.482096         14.095855
# ..   ...   ...    ...                 ...               ...               ...
# 940    0  22.0  116.0     Healthy control         41.851823         36.771496
# 941    0  26.0  118.0     Healthy control         18.986856         19.401387
# 942    0  26.0  113.0     Healthy control         28.781317         32.369230
# 943    0  24.0  107.0     Healthy control         19.929100         25.196375
# 944    0  21.0  105.0     Healthy control         65.195346         69.241972
#
# ...

# %%
# import pandas as pd
# from sklearn.decomposition import PCA
# from sklearn.ensemble import RandomForestClassifier

# # Assuming you have already trained your RandomForestClassifier model
# # and saved it as 'rf_model.pkl'
# import pickle


# rf_model = loaded_model

# # Load the dataset
# def load_data(filename):
#     df = pd.read_csv(filename)  # Assuming your data is stored in a CSV file
#     return df

# # Define a function to preprocess the data and perform PCA
# def preprocess_and_pca(df):
#     # Drop the columns you mentioned: sex, iq, age
#     # df_processed = df.drop(columns=['sex', 'iq', 'age'])

#     # Perform PCA
#     X = df.drop(columns=['main.disorder'])  # Features

#     # Standardize the features
#     scaler = StandardScaler()
#     X_scaled = scaler.fit_transform(X)

#     pca = PCA(n_components=20)
#     X_pca = pca.fit_transform(X_scaled)

#     pca = PCA(n_components=20)  # Select the number of components you want
#     pca_data = pca.fit_transform(df_processed)

#     return pca_data

# # Define a function to predict using the preprocessed data
# def predict_with_model(pca_data):
#     # Use the trained RandomForestClassifier model to predict
#     predicted_labels = rf_model.predict(pca_data)
#     return predicted_labels

# # Define a function to encapsulate the entire prediction process
# def predict_mental_disorder(filename):
#     # Load the data
#     df = load_data(filename)

#     # Preprocess the data and perform PCA
#     pca_data = preprocess_and_pca(df)

#     # Predict using the model
#     predicted_labels = predict_with_model(pca_data)

#     return predicted_labels

# # Example usage:
# # if __name__ == "__main__":
# #     # Pass the filename of your input data
# #     filename = 'your_input_data.csv'
# #     predicted_labels = predict_mental_disorder(filename)
# #     print(predicted_labels)

# %%
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier

# Assuming you have already trained your RandomForestClassifier model
# and saved it as 'rf_model.pkl'
import pickle


rf_model = loaded_model

# Load the dataset
def load_data(filename):
    df = pd.read_csv(filename)  # Assuming your data is stored in a CSV file
    return df

# Define a function to preprocess the data and perform PCA
def preprocess_and_pca(df):


    with open('/content/pca_model.pkl', 'rb') as file:
      pca = pickle.load(file)


    # Perform PCA
    X = df.drop(columns=['main.disorder'])  # Features

    # Standardize the features
    # scaler = StandardScaler()
    # X_scaled = scaler.fit_transform(X)

    pca_data = pca.transform(X)

    return pca_data

# Define a function to predict using the preprocessed data
def predict_with_model(pca_data):
    # Use the trained RandomForestClassifier model to predict
    predicted_labels = rf_model.predict(pca_data)
    return predicted_labels

# Define a function to encapsulate the entire prediction process
def predict_mental_disorder(filename):
    # Load the data
    df = load_data(filename)

    # Preprocess the data and perform PCA
    pca_data = preprocess_and_pca(df)

    # Predict using the model
    predicted_labels = predict_with_model(pca_data)

    return predicted_labels

# Example usage:
# if __name__ == "__main__":
#     # Pass the filename of your input data
#     filename = 'your_input_data.csv'
#     predicted_labels = predict_mental_disorder(filename)
#     print(predicted_labels)

# %%
dfe = df3

# Select entries for prediction (for example, select the first 5 entries)
entries_for_prediction = dfe.iloc[894:895]



pca_data = preprocess_and_pca(entries_for_prediction)

predicted_labels = predict_with_model(pca_data)


print("Predicted labels:", predicted_labels)
# Out:
# Predicted labels: ['Trauma and stress related disorder']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but PCA was fitted without feature names
#   warnings.warn(
